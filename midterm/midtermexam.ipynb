# %% [markdown]
# <a href="https://colab.research.google.com/github/carlxen/CCMACLRL_EXERCISES_COM232/blob/main/midtermexam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score

# %% [markdown]
# # Checking Data

# %%
dataset_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/train.csv?raw=true'
traindata = pd.read_csv(dataset_url)
traindata.head()
# Out:
#    id  MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0   0                 5                   8                5              8
# 1   1                 6                   7                4              4
# 2   2                 6                   5                6              7
# 3   3                 3                   4                6              5
# 4   4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    ...  DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 0  ...                5                     3           3           5
# 1  ...                7                     2           0           3
# 2  ...                7                     3           7           5
# 3  ...                2                     4           7           4
# 4  ...                2                     2           6           6
#
#    DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                            4                7            5
# 1                            5                3            3
# 2                            6                8            2
# 3                            4                6            5
# 4                            4                1            2
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   7                 3             0.445
# 1                   4                 3             0.450
# 2                   3                 3             0.530
# 3                   7                 5             0.535
# 4                   3                 5             0.415
#
# [5 rows x 22 columns]

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117957 entries, 0 to 1117956
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   id                               1117957 non-null  int64
#  1   MonsoonIntensity                 1117957 non-null  int64
#  2   TopographyDrainage               1117957 non-null  int64
#  3   RiverManagement                  1117957 non-null  int64
#  4   Deforestation                    1117957 non-null  int64
#  5   Urbanization                     1117957 non-null  int64
#  6   ClimateChange                    1117957 non-null  int64
#  7   DamsQuality                      1117957 non-null  int64
#  8   Siltation                        1117957 non-null  int64
#  9   AgriculturalPractices            1117957 non-null  int64
#  10  Encroachments                    1117957 non-null  int64
#  11  IneffectiveDisasterPreparedness  1117957 non-null  int64
#  12  DrainageSystems                  1117957 non-null  int64
#  13  CoastalVulnerability             1117957 non-null  int64
#  14  Landslides                       1117957 non-null  int64
#  15  Watersheds                       1117957 non-null  int64
#  16  DeterioratingInfrastructure      1117957 non-null  int64
#  17  PopulationScore                  1117957 non-null  int64
#  18  WetlandLoss                      1117957 non-null  int64
#  19  InadequatePlanning               1117957 non-null  int64
#  20  PoliticalFactors                 1117957 non-null  int64
#  21  FloodProbability                 1117957 non-null  float64
# dtypes: float64(1), int64(21)
# memory usage: 187.6 MB

# %%
traindata.shape
# Out:
# (1117957, 22)

# %%
traindata.describe()
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1.117957e+06      1.117957e+06        1.117957e+06     1.117957e+06
# mean   5.589780e+05      4.921450e+00        4.926671e+00     4.955322e+00
# std    3.227265e+05      2.056387e+00        2.093879e+00     2.072186e+00
# min    0.000000e+00      0.000000e+00        0.000000e+00     0.000000e+00
# 25%    2.794890e+05      3.000000e+00        3.000000e+00     4.000000e+00
# 50%    5.589780e+05      5.000000e+00        5.000000e+00     5.000000e+00
# 75%    8.384670e+05      6.000000e+00        6.000000e+00     6.000000e+00
# max    1.117956e+06      1.600000e+01        1.800000e+01     1.600000e+01
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   1.117957e+06  1.117957e+06   1.117957e+06  1.117957e+06  1.117957e+06
# mean    4.942240e+00  4.942517e+00   4.934093e+00  4.955878e+00  4.927791e+00
# std     2.051689e+00  2.083391e+00   2.057742e+00  2.083063e+00  2.065992e+00
# min     0.000000e+00  0.000000e+00   0.000000e+00  0.000000e+00  0.000000e+00
# 25%     4.000000e+00  3.000000e+00   3.000000e+00  4.000000e+00  3.000000e+00
# 50%     5.000000e+00  5.000000e+00   5.000000e+00  5.000000e+00  5.000000e+00
# 75%     6.000000e+00  6.000000e+00   6.000000e+00  6.000000e+00  6.000000e+00
# max     1.700000e+01  1.700000e+01   1.700000e+01  1.600000e+01  1.600000e+01
#
#        AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# count           1.117957e+06  ...     1.117957e+06          1.117957e+06
# mean            4.942619e+00  ...     4.946893e+00          4.953999e+00
# std             2.068545e+00  ...     2.072333e+00          2.088899e+00
# min             0.000000e+00  ...     0.000000e+00          0.000000e+00
# 25%             3.000000e+00  ...     4.000000e+00          3.000000e+00
# 50%             5.000000e+00  ...     5.000000e+00          5.000000e+00
# 75%             6.000000e+00  ...     6.000000e+00          6.000000e+00
# max             1.600000e+01  ...     1.700000e+01          1.700000e+01
#
#          Landslides    Watersheds  DeterioratingInfrastructure  \
# count  1.117957e+06  1.117957e+06                 1.117957e+06
# mean   4.931376e+00  4.929032e+00                 4.925907e+00
# std    2.078287e+00  2.082395e+00                 2.064813e+00
# min    0.000000e+00  0.000000e+00                 0.000000e+00
# 25%    3.000000e+00  3.000000e+00                 3.000000e+00
# 50%    5.000000e+00  5.000000e+00                 5.000000e+00
# 75%    6.000000e+00  6.000000e+00                 6.000000e+00
# max    1.600000e+01  1.600000e+01                 1.700000e+01
#
#        PopulationScore   WetlandLoss  InadequatePlanning  PoliticalFactors  \
# count     1.117957e+06  1.117957e+06        1.117957e+06      1.117957e+06
# mean      4.927520e+00  4.950859e+00        4.940587e+00      4.939004e+00
# std       2.074176e+00  2.068696e+00        2.081123e+00      2.090350e+00
# min       0.000000e+00  0.000000e+00        0.000000e+00      0.000000e+00
# 25%       3.000000e+00  4.000000e+00        3.000000e+00      3.000000e+00
# 50%       5.000000e+00  5.000000e+00        5.000000e+00      5.000000e+00
# 75%       6.000000e+00  6.000000e+00        6.000000e+00      6.000000e+00
# max       1.800000e+01  1.900000e+01        1.600000e+01      1.600000e+01
#
#        FloodProbability
# count      1.117957e+06
# mean       5.044803e-01
# std        5.102610e-02
# min        2.850000e-01
# 25%        4.700000e-01
# 50%        5.050000e-01
# 75%        5.400000e-01
# max        7.250000e-01
#
# [8 rows x 22 columns]

# %%
traindata.isnull().sum()
# Out:
# id                                 0
# MonsoonIntensity                   0
# TopographyDrainage                 0
# RiverManagement                    0
# Deforestation                      0
# Urbanization                       0
# ClimateChange                      0
# DamsQuality                        0
# Siltation                          0
# AgriculturalPractices              0
# Encroachments                      0
# IneffectiveDisasterPreparedness    0
# DrainageSystems                    0
# CoastalVulnerability               0
# Landslides                         0
# Watersheds                         0
# DeterioratingInfrastructure        0
# PopulationScore                    0
# WetlandLoss                        0
# InadequatePlanning                 0
# PoliticalFactors                   0
# FloodProbability                   0
# dtype: int64

# %%
traindata.duplicated().sum()
# Out:
# np.int64(0)

# %%
traindata.drop('id', axis=1, inplace=True)

# %%
correlation = traindata.corr()
correlation
# Out:
#                                  MonsoonIntensity  TopographyDrainage  \
# MonsoonIntensity                         1.000000           -0.007362
# TopographyDrainage                      -0.007362            1.000000
# RiverManagement                         -0.008070           -0.009924
# Deforestation                           -0.007251           -0.008548
# Urbanization                            -0.009309           -0.010532
# ClimateChange                           -0.008031           -0.009619
# DamsQuality                             -0.007787           -0.007607
# Siltation                               -0.007836           -0.009824
# AgriculturalPractices                   -0.008232           -0.009496
# Encroachments                           -0.010309           -0.012887
# IneffectiveDisasterPreparedness         -0.008032           -0.010746
# DrainageSystems                         -0.009716           -0.010056
# CoastalVulnerability                    -0.010659           -0.012526
# Landslides                              -0.009121           -0.010240
# Watersheds                              -0.008900           -0.011067
# DeterioratingInfrastructure             -0.008486           -0.006628
# PopulationScore                         -0.008679           -0.010815
# WetlandLoss                             -0.006811           -0.010267
# InadequatePlanning                      -0.008155           -0.011617
# PoliticalFactors                        -0.008474           -0.012350
# FloodProbability                         0.189098            0.187635
#
#                                  RiverManagement  Deforestation  Urbanization  \
# MonsoonIntensity                       -0.008070      -0.007251     -0.009309
# TopographyDrainage                     -0.009924      -0.008548     -0.010532
# RiverManagement                         1.000000      -0.008574     -0.012292
# Deforestation                          -0.008574       1.000000     -0.012248
# Urbanization                           -0.012292      -0.012248      1.000000
# ClimateChange                          -0.009237      -0.008266     -0.011199
# DamsQuality                            -0.008711      -0.009356     -0.011128
# Siltation                              -0.010058      -0.011536     -0.010153
# AgriculturalPractices                  -0.010783      -0.010039     -0.010559
# Encroachments                          -0.011615      -0.013175     -0.010784
# IneffectiveDisasterPreparedness        -0.010675      -0.009512     -0.012685
# DrainageSystems                        -0.011277      -0.010490     -0.012572
# CoastalVulnerability                   -0.011680      -0.012388     -0.014497
# Landslides                             -0.008994      -0.009257     -0.010582
# Watersheds                             -0.011412      -0.010671     -0.012107
# DeterioratingInfrastructure            -0.005827      -0.008862     -0.010656
# PopulationScore                        -0.006727      -0.011777     -0.011485
# WetlandLoss                            -0.010069      -0.011004     -0.011023
# InadequatePlanning                     -0.009673      -0.010424     -0.011584
# PoliticalFactors                       -0.011550      -0.009661     -0.013005
# FloodProbability                        0.187131       0.184001      0.180861
#
#                                  ClimateChange  DamsQuality  Siltation  \
# MonsoonIntensity                     -0.008031    -0.007787  -0.007836
# TopographyDrainage                   -0.009619    -0.007607  -0.009824
# RiverManagement                      -0.009237    -0.008711  -0.010058
# Deforestation                        -0.008266    -0.009356  -0.011536
# Urbanization                         -0.011199    -0.011128  -0.010153
# ClimateChange                         1.000000    -0.008427  -0.009457
# DamsQuality                          -0.008427     1.000000  -0.009401
# Siltation                            -0.009457    -0.009401   1.000000
# AgriculturalPractices                -0.011517    -0.009033  -0.010179
# Encroachments                        -0.012533    -0.010890  -0.010628
# IneffectiveDisasterPreparedness      -0.011346    -0.009515  -0.009099
# DrainageSystems                      -0.009650    -0.010439  -0.010702
# CoastalVulnerability                 -0.013005    -0.012096  -0.011762
# Landslides                           -0.009352    -0.009924  -0.009173
# Watersheds                           -0.009882    -0.009085  -0.009457
# DeterioratingInfrastructure          -0.006324    -0.009831  -0.006312
# PopulationScore                      -0.010332    -0.009599  -0.008739
# WetlandLoss                          -0.009376    -0.009372  -0.008667
# InadequatePlanning                   -0.010772    -0.011374  -0.009079
# PoliticalFactors                     -0.011379    -0.013081  -0.008493
# FloodProbability                      0.184761     0.187996   0.186789
#
#                                  AgriculturalPractices  Encroachments  ...  \
# MonsoonIntensity                             -0.008232      -0.010309  ...
# TopographyDrainage                           -0.009496      -0.012887  ...
# RiverManagement                              -0.010783      -0.011615  ...
# Deforestation                                -0.010039      -0.013175  ...
# Urbanization                                 -0.010559      -0.010784  ...
# ClimateChange                                -0.011517      -0.012533  ...
# DamsQuality                                  -0.009033      -0.010890  ...
# Siltation                                    -0.010179      -0.010628  ...
# AgriculturalPractices                         1.000000      -0.012244  ...
# Encroachments                                -0.012244       1.000000  ...
# IneffectiveDisasterPreparedness              -0.010763      -0.012211  ...
# DrainageSystems                              -0.010845      -0.011994  ...
# CoastalVulnerability                         -0.011415      -0.016203  ...
# Landslides                                   -0.010624      -0.011299  ...
# Watersheds                                   -0.009901      -0.013542  ...
# DeterioratingInfrastructure                  -0.008708      -0.010404  ...
# PopulationScore                              -0.008958      -0.010645  ...
# WetlandLoss                                  -0.011392      -0.010364  ...
# InadequatePlanning                           -0.010418      -0.012175  ...
# PoliticalFactors                             -0.011157      -0.011860  ...
# FloodProbability                              0.183366       0.178841  ...
#
#                                  DrainageSystems  CoastalVulnerability  \
# MonsoonIntensity                       -0.009716             -0.010659
# TopographyDrainage                     -0.010056             -0.012526
# RiverManagement                        -0.011277             -0.011680
# Deforestation                          -0.010490             -0.012388
# Urbanization                           -0.012572             -0.014497
# ClimateChange                          -0.009650             -0.013005
# DamsQuality                            -0.010439             -0.012096
# Siltation                              -0.010702             -0.011762
# AgriculturalPractices                  -0.010845             -0.011415
# Encroachments                          -0.011994             -0.016203
# IneffectiveDisasterPreparedness        -0.012613             -0.009798
# DrainageSystems                         1.000000             -0.013467
# CoastalVulnerability                   -0.013467              1.000000
# Landslides                             -0.011215             -0.013177
# Watersheds                             -0.012690             -0.012018
# DeterioratingInfrastructure            -0.009601             -0.009699
# PopulationScore                        -0.011975             -0.013256
# WetlandLoss                            -0.011199             -0.011989
# InadequatePlanning                     -0.013060             -0.014006
# PoliticalFactors                       -0.012244             -0.013275
# FloodProbability                        0.179305              0.177774
#
#                                  Landslides  Watersheds  \
# MonsoonIntensity                  -0.009121   -0.008900
# TopographyDrainage                -0.010240   -0.011067
# RiverManagement                   -0.008994   -0.011412
# Deforestation                     -0.009257   -0.010671
# Urbanization                      -0.010582   -0.012107
# ClimateChange                     -0.009352   -0.009882
# DamsQuality                       -0.009924   -0.009085
# Siltation                         -0.009173   -0.009457
# AgriculturalPractices             -0.010624   -0.009901
# Encroachments                     -0.011299   -0.013542
# IneffectiveDisasterPreparedness   -0.009669   -0.011588
# DrainageSystems                   -0.011215   -0.012690
# CoastalVulnerability              -0.013177   -0.012018
# Landslides                         1.000000   -0.012123
# Watersheds                        -0.012123    1.000000
# DeterioratingInfrastructure       -0.007216   -0.009812
# PopulationScore                   -0.008959   -0.010315
# WetlandLoss                       -0.011226   -0.012403
# InadequatePlanning                -0.011052   -0.013059
# PoliticalFactors                  -0.010277   -0.011324
# FloodProbability                   0.185346    0.181907
#
#                                  DeterioratingInfrastructure  PopulationScore  \
# MonsoonIntensity                                   -0.008486        -0.008679
# TopographyDrainage                                 -0.006628        -0.010815
# RiverManagement                                    -0.005827        -0.006727
# Deforestation                                      -0.008862        -0.011777
# Urbanization                                       -0.010656        -0.011485
# ClimateChange                                      -0.006324        -0.010332
# DamsQuality                                        -0.009831        -0.009599
# Siltation                                          -0.006312        -0.008739
# AgriculturalPractices                              -0.008708        -0.008958
# Encroachments                                      -0.010404        -0.010645
# IneffectiveDisasterPreparedness                    -0.009871        -0.011893
# DrainageSystems                                    -0.009601        -0.011975
# CoastalVulnerability                               -0.009699        -0.013256
# Landslides                                         -0.007216        -0.008959
# Watersheds                                         -0.009812        -0.010315
# DeterioratingInfrastructure                         1.000000        -0.007608
# PopulationScore                                    -0.007608         1.000000
# WetlandLoss                                        -0.008607        -0.011128
# InadequatePlanning                                 -0.008214        -0.009847
# PoliticalFactors                                   -0.009388        -0.012772
# FloodProbability                                    0.190007         0.185890
#
#                                  WetlandLoss  InadequatePlanning  \
# MonsoonIntensity                   -0.006811           -0.008155
# TopographyDrainage                 -0.010267           -0.011617
# RiverManagement                    -0.010069           -0.009673
# Deforestation                      -0.011004           -0.010424
# Urbanization                       -0.011023           -0.011584
# ClimateChange                      -0.009376           -0.010772
# DamsQuality                        -0.009372           -0.011374
# Siltation                          -0.008667           -0.009079
# AgriculturalPractices              -0.011392           -0.010418
# Encroachments                      -0.010364           -0.012175
# IneffectiveDisasterPreparedness    -0.010299           -0.012080
# DrainageSystems                    -0.011199           -0.013060
# CoastalVulnerability               -0.011989           -0.014006
# Landslides                         -0.011226           -0.011052
# Watersheds                         -0.012403           -0.013059
# DeterioratingInfrastructure        -0.008607           -0.008214
# PopulationScore                    -0.011128           -0.009847
# WetlandLoss                         1.000000           -0.009830
# InadequatePlanning                 -0.009830            1.000000
# PoliticalFactors                   -0.011061           -0.011540
# FloodProbability                    0.183396            0.180968
#
#                                  PoliticalFactors  FloodProbability
# MonsoonIntensity                        -0.008474          0.189098
# TopographyDrainage                      -0.012350          0.187635
# RiverManagement                         -0.011550          0.187131
# Deforestation                           -0.009661          0.184001
# Urbanization                            -0.013005          0.180861
# ClimateChange                           -0.011379          0.184761
# DamsQuality                             -0.013081          0.187996
# Siltation                               -0.008493          0.186789
# AgriculturalPractices                   -0.011157          0.183366
# Encroachments                           -0.011860          0.178841
# IneffectiveDisasterPreparedness         -0.010563          0.183109
# DrainageSystems                         -0.012244          0.179305
# CoastalVulnerability                    -0.013275          0.177774
# Landslides                              -0.010277          0.185346
# Watersheds                              -0.011324          0.181907
# DeterioratingInfrastructure             -0.009388          0.190007
# PopulationScore                         -0.012772          0.185890
# WetlandLoss                             -0.011061          0.183396
# InadequatePlanning                      -0.011540          0.180968
# PoliticalFactors                         1.000000          0.182417
# FloodProbability                         0.182417          1.000000
#
# [21 rows x 21 columns]

# %%
sns.heatmap(correlation, vmin=-1, vmax=1, center=0)
# Out:
# <Axes: >

# %% [markdown]
# # Training Data - Linear Regression

# %%
traindata.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 5                   8                5              8
# 1                 6                   7                4              4
# 2                 6                   5                6              7
# 3                 3                   4                6              5
# 4                 5                   3                2              6
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              4            4          3                      3
# 1             8              8            3          5                      4
# 2             3              7            1          5                      4
# 3             4              8            4          7                      6
# 4             4              4            3          3                      3
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              4  ...                5                     3           3
# 1              6  ...                7                     2           0
# 2              5  ...                7                     3           7
# 3              8  ...                2                     4           7
# 4              3  ...                2                     2           6
#
#    Watersheds  DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0           5                            4                7            5
# 1           3                            5                3            3
# 2           5                            6                8            2
# 3           4                            4                6            5
# 4           6                            4                1            2
#
#    InadequatePlanning  PoliticalFactors  FloodProbability
# 0                   7                 3             0.445
# 1                   4                 3             0.450
# 2                   3                 3             0.530
# 3                   7                 5             0.535
# 4                   3                 5             0.415
#
# [5 rows x 21 columns]

# %%
X = traindata[['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement', 'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality', 'Siltation', 'AgriculturalPractices', 'Encroachments', 'IneffectiveDisasterPreparedness', 'DrainageSystems', 'CoastalVulnerability', 'Landslides', 'Watersheds', 'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss', 'InadequatePlanning', 'PoliticalFactors']]
y = traindata['FloodProbability']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=466)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (894365, 20) (223592, 20) (894365,) (223592,)

# %%
modelv1= LinearRegression()

# %%
modelv1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Test File

# %%
test_url = 'https://github.com/robitussin/CCMACLRL_EXAM/blob/ebd51da1dafde093c18d9e8f35c834d91b2887f7/datasets/test.csv?raw=true'
testdata = pd.read_csv(test_url)

# %%
testdata.drop('id', axis=1, inplace=True)

# %%
testdata.head()
# Out:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 4                   6                3              5
# 1                 4                   4                2              9
# 2                 1                   3                6              5
# 3                 2                   4                4              6
# 4                 6                   3                2              4
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             6              7            8          7                      8
# 1             5              5            4          7                      5
# 2             7              2            4          6                      4
# 3             4              5            4          3                      4
# 4             6              4            5          5                      3
#
#    Encroachments  IneffectiveDisasterPreparedness  DrainageSystems  \
# 0              4                                8                5
# 1              4                                2                4
# 2              2                                7                9
# 3              4                                7                8
# 4              7                                4                3
#
#    CoastalVulnerability  Landslides  Watersheds  DeterioratingInfrastructure  \
# 0                     7           5           6                            3
# 1                     7           4           5                            1
# 2                     2           5           5                            2
# 3                     4           6           7                            6
# 4                     2           6           4                            6
#
#    PopulationScore  WetlandLoss  InadequatePlanning  PoliticalFactors
# 0                6            4                   4                 5
# 1                7            4                   4                 3
# 2                3            6                   8                 3
# 3                4            2                   4                 4
# 4                8            4                   5                 5

# %%
y_pred = modelv1.predict(testdata)

# %%
print('R2 Score:', r2_score(y_test, modelv1.predict(X_test)))
print('Mean Squared Error:', mean_squared_error(y_test, modelv1.predict(X_test)))
# Out:
# R2 Score: 0.8452684869607293
# Mean Squared Error: 0.00040237678075752317

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x=y_test,
            y=modelv1.predict(X_test),
            scatter_kws={'alpha': 0.5, 'color':'purple'},
            line_kws={'color': 'pink'})
plt.xlabel('Actual Flood Probability')
plt.ylabel('Predicted Flood Probability')
plt.title('Flood Probability')
plt.show()

# %% [markdown]
# The "Flood Probability" scatter plot compares the actual vs the predicted flood probabilities. Actual values are on the x-axis, while the predicted values are on the y-axis. With purple dots showing observations and a pink line indicating **perfect prediction**.

# %% [markdown]
# # Submission File

# %%
# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'FloodProbability': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('submission_file.csv', index=False)
print("Submission file created: submission_file.csv")
# Out:
# Submission file created: submission_file.csv
